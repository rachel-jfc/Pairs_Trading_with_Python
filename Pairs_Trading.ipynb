# %%
import pandas as pd
import numpy as np
import yfinance as yf
import statsmodels.api as sm
import scipy.optimize as spop

import matplotlib.pyplot as plt
plt.rcParams['figure.figsize'] = (12, 8)
# %matplotlib inline

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## 1. Loading Data

# %% [markdown]
# Get a list of tech stocks from the S&P 500 companies

# %%
payload=pd.read_html('https://en.wikipedia.org/wiki/List_of_S%26P_500_companies')
first_table = payload[0]
df = first_table[first_table['GICS Sector']=='Information Technology']
tickers = df['Symbol'].values.tolist()
tickers
# Out:
# ['ACN',
#  'ADBE',
#  'ADP',
#  'AKAM',
#  'AMD',
#  'APH',
#  'ADI',
#  'ANSS',
#  'AAPL',
#  'AMAT',
#  'ANET',
#  'ADSK',
#  'AVGO',
#  'BR',
#  'CDNS',
#  'CDW',
#  'CDAY',
#  'CSCO',
#  'CTXS',
#  'CTSH',
#  'GLW',
#  'DXC',
#  'ENPH',
#  'EPAM',
#  'FFIV',
#  'FIS',
#  'FISV',
#  'FLT',
#  'FTNT',
#  'IT',
#  'GPN',
#  'HPE',
#  'HPQ',
#  'IBM',
#  'INTC',
#  'INTU',
#  'JKHY',
#  'JNPR',
#  'KEYS',
#  'KLAC',
#  'LRCX',
#  'MA',
#  'MCHP',
#  'MU',
#  'MSFT',
#  'MPWR',
#  'MSI',
#  'NTAP',
#  'NLOK',
#  'NVDA',
#  'NXPI',
#  'ON',
#  'ORCL',
#  'PAYX',
#  'PAYC',
#  'PYPL',
#  'PTC',
#  'QRVO',
#  'QCOM',
#  'CRM',
#  'STX',
#  'NOW',
#  'SWKS',
#  'SEDG',
#  'SNPS',
#  'TEL',
#  'TER',
#  'TXN',
#  'TRMB',
#  'TYL',
#  'VRSN',
#  'V',
#  'WDC',
#  'ZBRA']

# %%
start_date = '2020-07-01'
end_date = '2022-06-30'
final_dataframe = pd.DataFrame()

for symbol in tickers:
    stock_daily=yf.download(symbol, start_date, end_date)
    stock_daily.insert(0,'Ticker', symbol)
    final_dataframe = pd.concat([final_dataframe, stock_daily])

final_dataframe.reset_index(level=0, inplace=True)
final_dataframe = final_dataframe.rename({'index': 'Date'}, axis=1)
# Out:
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed
# [*********************100%***********************]  1 of 1 completed

# %%
final_dataframe.head()
# Out:
#         Date Ticker        Open        High         Low       Close  \
# 0 2020-07-01    ACN  214.500000  216.899994  213.880005  214.589996
# 1 2020-07-02    ACN  216.570007  218.449997  214.899994  215.720001
# 2 2020-07-06    ACN  217.759995  219.660004  216.309998  217.550003
# 3 2020-07-07    ACN  216.320007  219.869995  216.119995  216.330002
# 4 2020-07-08    ACN  217.470001  219.149994  216.339996  218.889999
#
#     Adj Close   Volume
# 0  208.463974  2124700
# 1  209.561707  2006200
# 2  211.339478  1934500
# 3  210.154282  1783700
# 4  212.641235  1750700

# %% [markdown]
# ## 2. Pairs Trading Strategy

# %% [markdown]
# Tech stock with their adj close price

# %%
pt_df = final_dataframe[['Date', 'Ticker', 'Adj Close']].sort_values(by = ['Date', 'Ticker'])
pt_df = pt_df.dropna(subset=['Adj Close'])
pt_df = pt_df.pivot(index = 'Date', columns = 'Ticker', values = 'Adj Close')
pt_df.head()
# Out:
# Ticker           AAPL         ACN        ADBE         ADI         ADP  \
# Date
# 2020-07-01  89.779900  208.463974  439.809998  116.157661  143.185425
# 2020-07-02  89.779900  209.561707  442.950012  116.997215  144.558624
# 2020-07-06  92.181526  211.339478  452.589996  119.293930  144.741074
# 2020-07-07  91.895508  210.154282  449.359985  118.328918  141.159286
# 2020-07-08  94.035767  212.641235  457.679993  118.560532  142.215591
#
# Ticker            ADSK        AKAM       AMAT        AMD       ANET  ...  \
# Date                                                                 ...
# 2020-07-01  241.220001  106.330002  58.638412  52.580002  52.360001  ...
# 2020-07-02  240.149994  113.120003  59.935375  52.340000  52.627499  ...
# 2020-07-06  244.360001  112.610001  62.352440  53.400002  53.612499  ...
# 2020-07-07  238.940002  110.980003  61.094776  52.930000  52.695000  ...
# 2020-07-08  243.899994  112.669998  61.674480  53.430000  53.525002  ...
#
# Ticker            SWKS        TEL        TER       TRMB         TXN  \
# Date
# 2020-07-01  122.274719  77.276726  82.325668  42.750000  117.860344
# 2020-07-02  124.771698  78.068237  83.983879  42.520000  118.814186
# 2020-07-06  127.715630  79.631905  87.508873  43.430000  122.327332
# 2020-07-07  128.522049  78.019966  85.731483  42.040001  121.449051
# 2020-07-08  128.395721  77.305695  87.131561  42.400002  122.072350
#
# Ticker             TYL           V        VRSN        WDC        ZBRA
# Date
# 2020-07-01  350.320007  191.001251  210.479996  42.450001  251.229996
# 2020-07-02  355.220001  192.864166  210.809998  42.439999  255.039993
# 2020-07-06  352.470001  194.924194  212.199997  42.950001  261.630005
# 2020-07-07  352.519989  191.415207  211.110001  41.720001  254.259995
# 2020-07-08  355.040009  192.272766  210.800003  42.799999  257.209991
#
# [5 rows x 74 columns]

# %% [markdown]
# ### Find pairs

# %%
from statsmodels.tsa.stattools import coint
import seaborn

# %%
def find_cointegrated_pairs(data):
    n = data.shape[1] 
    pvalue_matrix = np.ones((n, n))
    keys = data.keys()
    pairs = {"S1":[], 'S2':[], 'pvalue':[]}
    
    for i in range(n):
        for j in range(i+1, n):
            S1 = data[keys[i]]
            S2 = data[keys[j]]
            result = coint(S1, S2)
            pvalue = result[1]
            pvalue_matrix[i, j] = pvalue
            if pvalue < 0.05:
                pairs['S1'].append(keys[i]) 
                pairs['S2'].append(keys[j]) 
                pairs['pvalue'].append(pvalue)   
                    
    return pvalue_matrix, pairs

# %%
pairs = find_cointegrated_pairs(pt_df)

# %% [markdown]
# p value for each pair of stocks

# %%
names = pt_df.keys().to_list()
df1 = pd.DataFrame(pairs[0], index=names, columns=names)
df1.head()
# Out:
#       AAPL       ACN      ADBE       ADI       ADP      ADSK      AKAM  \
# AAPL   1.0  0.091503  0.498870  0.303912  0.144977  0.330460  0.411365
# ACN    1.0  1.000000  0.834347  0.307908  0.649731  0.741014  0.680705
# ADBE   1.0  1.000000  1.000000  0.921077  0.923165  0.542329  0.533237
# ADI    1.0  1.000000  1.000000  1.000000  0.436065  0.668932  0.538788
# ADP    1.0  1.000000  1.000000  1.000000  1.000000  0.808753  0.815845
#
#           AMAT       AMD      ANET  ...      SWKS       TEL       TER  \
# AAPL  0.481903  0.398259  0.006581  ...  0.334309  0.419262  0.475464
# ACN   0.585589  0.312760  0.371510  ...  0.743453  0.295625  0.623458
# ADBE  0.852066  0.852053  0.902882  ...  0.610590  0.765666  0.817475
# ADI   0.303056  0.659534  0.618293  ...  0.696030  0.052142  0.538613
# ADP   0.795721  0.815622  0.380619  ...  0.803928  0.870212  0.889236
#
#           TRMB       TXN       TYL         V      VRSN       WDC      ZBRA
# AAPL  0.678453  0.687029  0.617470  0.534445  0.385645  0.457783  0.633285
# ACN   0.881547  0.633135  0.774752  0.741063  0.713645  0.756907  0.862274
# ADBE  0.723014  0.830126  0.511192  0.697746  0.200083  0.810628  0.633378
# ADI   0.499273  0.181440  0.593104  0.474289  0.547478  0.549908  0.696752
# ADP   0.954193  0.840125  0.962006  0.783158  0.921119  0.893815  0.975237
#
# [5 rows x 74 columns]

# %% [markdown]
# Find top pairs with the lowest pvalue

# %%
df2 = pd.DataFrame.from_dict(pairs[1]).sort_values(by=['pvalue'])
df2.head()
# Out:
#       S1    S2    pvalue
# 100   MA   WDC  0.000381
# 6    ACN  MSFT  0.000808
# 75    MA    MU  0.000817
# 85    MA   PTC  0.001172
# 80    MA  NXPI  0.001569

# %% [markdown]
# ### Implement buy/sell
# **Rules:**
# - Go "Long" the ratio whenever the z-score is below -1.0
# - Go "Short" the ratio when the z-score is above 1.0
# - Exit positions when the z-score approaches zero
# - Trigger stop loss if our PnL declines 8% of our account size

# %% [markdown]
# ### Example
# ('ACN', 'MSFT')

# %%
from statsmodels.tsa.stattools import adfuller

# %% [markdown]
# #### Check for stationarity

# %%
S1 = pt_df['ACN']
S2 = pt_df['MSFT']

# %%
S1_ADF = adfuller(S1)
print('P value for the Augmented Dickey-Fuller Test is', S1_ADF[1])
S2_ADF = adfuller(S2)
print('P value for the Augmented Dickey-Fuller Test is', S2_ADF[1])
Spread_ADF = adfuller(S1 - S2)
print('P value for the Augmented Dickey-Fuller Test is', Spread_ADF[1])
Ratio_ADF = adfuller(S1 / S2)
print('P value for the Augmented Dickey-Fuller Test is', Ratio_ADF[1])
# Out:
# P value for the Augmented Dickey-Fuller Test is 0.43062742350949207
# P value for the Augmented Dickey-Fuller Test is 0.5041411867964508
# P value for the Augmented Dickey-Fuller Test is 0.00345720995969695
# P value for the Augmented Dickey-Fuller Test is 0.00016499575342812192

# %% [markdown]
# Results: can claim stationary for the spread and ration for P value < 0.05). This suggests a constant mean over time. Therefore, the two series are cointegrated.

# %% [markdown]
# #### Price Comparison

# %%
from matplotlib.pyplot import figure

# %%
# Correlation of Nike and Apple ~ 0.89.
figure(figsize=(8, 6), dpi=200)
plt.plot(S1, label = "ACN")
plt.plot(S2, label = "MSFT")
plt.title('Historical Adjusted Closing Prices')
plt.legend()
#plt.show()
plt.savefig('AdjustedPrice-ACNvsMSFT.jpg')

# %% [markdown]
# #### Calculate the Spread

# %%
S1_sm = sm.add_constant(S1)
results = sm.OLS(S2, S1).fit()
S1_sm = S1_sm['ACN']
b = results.params['ACN']

spread = S2 - b * S1
spread.plot(figsize=(12,6))
plt.axhline(spread.mean(), color='red')
plt.xlim('2020-07-01', '2022-06-30')
plt.legend(['Spread'])

# %% [markdown]
# #### ACN/MSFT Ratio

# %%
ratio = S1/S2
ratio.plot(figsize=(8,6))
plt.axhline(ratio.mean(), color='red')
plt.legend(['Price Ratio'])
#plt.show()
plt.savefig('PriceRatio.jpg')

# %% [markdown]
# Two stocks tend to move around together around the mean

# %% [markdown]
# #### Z-score

# %%
def zscore(series):
    return (series - series.mean()) / np.std(series)

# %%
zscore(ratio).plot(figsize=(15,7))
plt.axhline(zscore(ratio).mean(), color='black')
plt.axhline(1.0, color='red', linestyle='--')
plt.axhline(-1.0, color='green', linestyle='--')
plt.legend(['Ratio z-score', 'Mean', '+1', '-1'])
plt.show()

# %% [markdown]
# #### Feature engineering
# - 60 day Moving Average of Ratio
# - 5 day Moving Average of Ratio
# - 60 day Standard Deviation
# - z score

# %%
ratios_mavg5 = ratio.rolling(window=5, center=False).mean()

ratios_mavg60 = ratio.rolling(window=60, center=False).mean()

std_60 = ratio.rolling(window=60, center=False).std()

zscore_60_5 = (ratios_mavg5 - ratios_mavg60)/std_60
plt.figure(figsize=(15,7))
plt.plot(ratio.index, ratio.values)
plt.plot(ratios_mavg5.index, ratios_mavg5.values)
plt.plot(ratios_mavg60.index, ratios_mavg60.values)
plt.axhline(ratio.mean(), color='red')
#plt.xlim('2020-10-01','2022-06-30')
plt.legend(['Ratio','5d Ratio MA', '60d Ratio MA'])
plt.ylabel('Ratio')

#plt.show()
plt.savefig('RollingRatio.jpg')

# %% [markdown]
# #### Rolling Ratio z-score

# %%
figure(figsize=(8, 6), dpi=200)
zscore_60_5.plot()
plt.axhline(0, color='black')
plt.axhline(1, color='green', linestyle='--')
plt.axhline(-1, color='green', linestyle='--')
plt.xlim('2020-10-01','2022-06-30')
plt.legend(['Rolling Ratio z-score', 'Mean', '+1','-1'])
#plt.show()
plt.savefig('RollingRatioZscore.jpg')

# %% [markdown]
# When ACN/MSFT is above the upper band, we assume that the ACN>MSFT price will fall back to an equilibrium. In this case, we short ACN and long MSFT.
# When ACN/MSFT is below the lower band, we assume that the ACN<MSFT price will fall back to an equilibrium. In this case, we short MSFT and long ACN.

# %% [markdown]
# Sell: Buy ACN sell MSFT
# Buy: Buy MSFT sell ACN

# %% [markdown]
# #### Buy-Sell Plot

# %%
figure(figsize=(8, 6), dpi=200)
ratio.plot()
buy = ratio.copy()
sell = ratio.copy()
buy[zscore_60_5>-1] = 0
sell[zscore_60_5<1] = 0
buy.plot(color='g', linestyle='None', marker='^')
sell.plot(color='r', linestyle='None', marker='^')
x1, x2, y1, y2 = plt.axis()
plt.axis((x1, x2, ratio.min(), ratio.max()))
plt.xlim('2020-10-01','2022-06-30')
plt.legend(['Ratio', 'Buy Signal', 'Sell Signal'])
plt.title('Relationship ACN to MSFT')
plt.show()

# %%
# Plot the prices and buy and sell signals from z score
plt.figure(figsize=(18,9))

S1.plot(color='b')
S2.plot(color='c')
buyR = 0*S1.copy()
sellR = 0*S1.copy()

# When buying the ratio, buy S1 and sell S2
buyR[buy!=0] = S1[buy!=0]
sellR[buy!=0] = S2[buy!=0]
# When selling the ratio, sell S1 and buy S2 
buyR[sell!=0] = S2[sell!=0]
sellR[sell!=0] = S1[sell!=0]

buyR.plot(color='m', linestyle='None', marker='^')
sellR.plot(color='k', linestyle='None', marker='^')
x1,x2,y1,y2 = plt.axis()
plt.axis((x1,x2,min(S1.min(),S2.min()),max(S1.max(),S2.max())))
plt.xlim('2020-10-01','2022-06-30')
plt.legend(['ACN','MSFT', 'Buy Signal', 'Sell Signal'])
plt.show()

# %% [markdown]
# #### Model Tuning

# %%
def test(S1, S2, window1, window2):
    # Compute rolling mean and rolling standard deviation
    ratios = S1/S2
    ma1 = ratios.rolling(window=window1, center=False).mean()
    ma2 = ratios.rolling(window=window2, center=False).mean()
    std = ratios.rolling(window=window2, center=False).std()
    zscore = (ma1 - ma2)/std
    
    # Simulate trading
    # Start with $10,000 and no positions
    cash = float(10000)
    signal1 = 0
    signal2 = 0
    position1 = 0
    position2 = 0
    signals1 = np.array([])
    signals2 = np.array([])
    date = S1.index
    size1 = cash//max(S1)
    size2 = cash//max(S2)
    stop_loss = cash * 0.08 * -1
    portfolio = {"Position1":[], "Position2":[], "Cash":[]}
    
    for i in range(len(ratios)):
        # Sell short if the z-score is > 1
        if zscore[i] > 1:
            signal1 = -1
        # Buy long if the z-score is < 1
        elif zscore[i] < -1:
            signal1 = 1
        else:
            signal1 = 0
        
        signal2 = -signal1
        signals1 = np.append(signals1, signal1)
        signals2 = np.append(signals2, signal2)
        position1 = signals1[i] - signals1[i-1]
        position2 = signals2[i] - signals2[i-1]
        pnl = - position1*S1[i]*size1 - position2*S2[i]*size2
        if pnl < stop_loss:
            signals1[i] = 0
            signals2[i] = 0
            position1 = signals1[i] - signals1[i-1]
            position2 = signals2[i] - signals2[i-1]
            cash -= position1*S1[i]*size1 + position2*S2[i]*size2
#             print("stop-loss triggered")
        else:
            cash += pnl
        
    return cash

# %%
test_size = 0.2
train_size = int(len(S1) * (1-test_size))
S1_train, S1_test = S1[0:train_size], S1[train_size:len(S1)]
S2_train, S2_test = S2[0:train_size], S2[train_size:len(S1)]

# %%
# Find the window length 0-200
# that gives the highest returns using this strategy
length_scores = [test(S1_train, 
                S2_train, 5, l) 
                for l in range(200)]
best_length = np.argmax(length_scores)
print ('Best window length:', best_length)
# Out:
# Best window length: 56

# %%
# Find the returns for test data
# using what we think is the best window length
length_scores2 = [test(S1_test, 
                  S2_test, 5, l) 
                  for l in range(200)]
print (best_length, 'day window:', length_scores2[best_length])
# Find the best window length based on this dataset, 
# and the returns using this window length
best_length2 = np.argmax(length_scores2)
print (best_length2, 'day window:', length_scores2[best_length2])
# Out:
# 56 day window: 10459.954467773438
# 40 day window: 10787.050277709961

# %%
plt.figure(figsize=(15,7))
plt.plot(length_scores)
plt.plot(length_scores2)
plt.xlabel('Window length')
plt.ylabel('Score')
plt.legend(['Training', 'Test'])
#plt.show()
plt.savefig('ModelTuning.jpg')

# %%
print(f'Before tuning {test(S1, S2, 5, 60)}')
print(f'After tuning {test(S1, S2, 5, 56)}')
# Out:
# Before tuning 13888.185729980469
# After tuning 15009.808044433594

# %% [markdown]
# ## 3. Output

# %%
cash = float(10000)
size1 = cash//max(S1)
size2 = cash//max(S2)

# %%
size1
# Out:
# 24.0

# %%
size2
# Out:
# 29.0

# %%
def trade(S1, S2, window1, window2):
    # Compute rolling mean and rolling standard deviation
    ratios = S1/S2
    ma1 = ratios.rolling(window=window1, center=False).mean()
    ma2 = ratios.rolling(window=window2, center=False).mean()
    std = ratios.rolling(window=window2, center=False).std()
    zscore = (ma1 - ma2)/std
    
    # Simulate trading
    # Start with $10,000 and no positions
    cash = float(10000)
    signal1 = 0
    signal2 = 0
    position1 = 0
    position2 = 0
    signals1 = np.array([])
    signals2 = np.array([])
    date = S1.index
    size1 = cash//max(S1)
    size2 = cash//max(S2)
    stop_loss = cash * 0.08 * -1
    portfolio = {"Position1":[], "Position2":[], "Cash":[]}
    
    for i in range(len(ratios)):
        # Sell short if the z-score is > 1
        if zscore[i] > 1:
            signal1 = -1
        # Buy long if the z-score is < 1
        elif zscore[i] < -1:
            signal1 = 1
        else:
            signal1 = 0
        
        signal2 = -signal1
        signals1 = np.append(signals1, signal1)
        signals2 = np.append(signals2, signal2)
        position1 = signals1[i] - signals1[i-1]
        position2 = signals2[i] - signals2[i-1]
        pnl = - position1*S1[i]*size1 - position2*S2[i]*size2
        if pnl < stop_loss or abs(zscore[i]) < 0.5:
            signals1[i] = 0
            signals2[i] = 0
            position1 = signals1[i] - signals1[i-1]
            position2 = signals2[i] - signals2[i-1]
            cash -= position1*S1[i]*size1 + position2*S2[i]*size2
            print("stop-loss triggered")
        else:
            cash += pnl
        
        portfolio["Position1"].append(position1)
        portfolio["Position2"].append(position2)
        portfolio["Cash"].append(cash)
        print(f"Date {date[i]}, Position 1 {position1}, Position 2 {position2}, PNL {pnl}, Cash {cash}")
    
    return portfolio

# %% [markdown]
# #### Backtesting - how well the strategy would have done in the past two years

# %%
portfolio_ = trade(S1, S2, 5, 56)
# Out:
# Date 2020-07-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-07-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10000.0
# Date 2020-10-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10749.985610961914
# Date 2020-10-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10749.985610961914
# Date 2020-10-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10749.985610961914
# Date 2020-10-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10749.985610961914
# Date 2020-10-12 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 892.3800201416016, Cash 11642.365631103516
# Date 2020-10-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11642.365631103516
# Date 2020-10-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11642.365631103516
# Date 2020-10-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11642.365631103516
# Date 2020-10-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11642.365631103516
# Date 2020-10-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11642.365631103516
# Date 2020-10-20 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -704.7190551757812, Cash 10937.646575927734
# Date 2020-10-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-10-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# Date 2020-11-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2020-11-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 10937.646575927734
# stop-loss triggered
# Date 2021-02-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12589.747314453125
# Date 2021-02-24 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -605.4981689453125, Cash 11984.249145507812
# Date 2021-02-25 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# Date 2021-02-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# stop-loss triggered
# Date 2021-03-25 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# Date 2021-03-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# Date 2021-03-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11984.249145507812
# Date 2021-03-30 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -73.70269775390625, Cash 11910.546447753906
# Date 2021-03-31 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11910.546447753906
# Date 2021-04-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11910.546447753906
# Date 2021-04-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11910.546447753906
# Date 2021-04-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 11910.546447753906
# Date 2021-04-07 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 495.8593444824219, Cash 12406.405792236328
# Date 2021-04-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# Date 2021-04-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# Date 2021-04-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# stop-loss triggered
# Date 2021-04-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# stop-loss triggered
# Date 2021-04-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# stop-loss triggered
# Date 2021-04-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# stop-loss triggered
# Date 2021-04-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# stop-loss triggered
# Date 2021-04-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12406.405792236328
# Date 2021-07-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13288.737854003906
# Date 2021-07-07 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -714.3933410644531, Cash 12574.344512939453
# Date 2021-07-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-07-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-20 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-07-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-20 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-08-25 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-08-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# stop-loss triggered
# Date 2021-08-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-08-31 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-09-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-09-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12574.344512939453
# Date 2021-09-03 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -519.529052734375, Cash 12054.815460205078
# Date 2021-09-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12054.815460205078
# Date 2021-09-20 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 584.5936889648438, Cash 12639.409149169922
# Date 2021-09-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12639.409149169922
# stop-loss triggered
# Date 2021-09-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12639.409149169922
# Date 2021-09-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12639.409149169922
# Date 2021-09-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12639.409149169922
# Date 2021-09-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12639.409149169922
# Date 2021-09-28 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -466.1623840332031, Cash 12173.246765136719
# Date 2021-09-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12173.246765136719
# Date 2021-09-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12173.246765136719
# Date 2021-10-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12173.246765136719
# Date 2021-10-04 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 566.2914733886719, Cash 12739.53823852539
# Date 2021-10-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# Date 2021-10-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# Date 2021-10-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# Date 2021-10-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# stop-loss triggered
# Date 2021-10-20 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 12739.53823852539
# Date 2021-11-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14363.084197998047
# Date 2021-12-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14363.084197998047
# stop-loss triggered
# Date 2021-12-02 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -805.5195617675781, Cash 13557.564636230469
# Date 2021-12-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# stop-loss triggered
# Date 2021-12-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13557.564636230469
# Date 2021-12-16 00:00:00, Position 1 -1.0, Position 2 1.0, PNL 166.24169921875, Cash 13723.806335449219
# Date 2021-12-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-20 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2021-12-31 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13723.806335449219
# Date 2022-01-12 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 176.22259521484375, Cash 13900.028930664062
# Date 2022-01-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# Date 2022-01-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# Date 2022-01-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-20 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-25 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-01-31 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-02-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 13900.028930664062
# stop-loss triggered
# Date 2022-03-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15295.816467285156
# Date 2022-03-25 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15295.816467285156
# Date 2022-03-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15295.816467285156
# Date 2022-03-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15295.816467285156
# Date 2022-03-30 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15295.816467285156
# stop-loss triggered
# Date 2022-03-31 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -860.4287414550781, Cash 14435.387725830078
# Date 2022-04-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# Date 2022-04-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# stop-loss triggered
# Date 2022-04-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# stop-loss triggered
# Date 2022-04-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# stop-loss triggered
# Date 2022-04-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# Date 2022-04-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# Date 2022-04-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14435.387725830078
# Date 2022-04-12 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -352.91766357421875, Cash 14082.47006225586
# Date 2022-04-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14082.47006225586
# Date 2022-04-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14082.47006225586
# Date 2022-04-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14082.47006225586
# Date 2022-04-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14082.47006225586
# Date 2022-04-20 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 527.0468444824219, Cash 14609.516906738281
# Date 2022-04-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14609.516906738281
# Date 2022-04-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14609.516906738281
# Date 2022-04-25 00:00:00, Position 1 -1.0, Position 2 1.0, PNL -528.0301513671875, Cash 14081.486755371094
# Date 2022-04-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 14081.486755371094
# Date 2022-04-27 00:00:00, Position 1 1.0, Position 2 -1.0, PNL 928.3212890625, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-04-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-04-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-04 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-05 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-11 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-12 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-18 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-19 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-20 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-25 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-05-26 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-05-31 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-01 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-02 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-03 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-06 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-07 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-08 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-09 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-10 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-13 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-14 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-15 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-16 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# Date 2022-06-17 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-21 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-22 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-23 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-24 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-27 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-28 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594
# stop-loss triggered
# Date 2022-06-29 00:00:00, Position 1 0.0, Position 2 0.0, PNL -0.0, Cash 15009.808044433594

# %%
portfolio_df = pd.DataFrame.from_dict(portfolio_).set_index(S1.index)

# %%
portfolio_df.insert(0,'S2', S2)
portfolio_df.insert(0,'S1', S1)
portfolio_df.insert(4,"Holding2", portfolio_df['Position2'].cumsum()*portfolio_df['S2']*size2)
portfolio_df.insert(4,"Holding1", portfolio_df['Position1'].cumsum()*portfolio_df['S1']*size1)
portfolio_df['TotalAsset'] = portfolio_df['Holding1'] + portfolio_df['Holding2'] + portfolio_df['Cash']

# %%
portfolio_df
# Out:
#                     S1          S2  Position1  Position2  Holding1  Holding2  \
# Date
# 2020-07-01  208.463974  200.668991        0.0        0.0       0.0       0.0
# 2020-07-02  209.561707  202.198288        0.0        0.0       0.0       0.0
# 2020-07-06  211.339478  206.550873        0.0        0.0       0.0       0.0
# 2020-07-07  210.154282  204.149078        0.0        0.0       0.0       0.0
# 2020-07-08  212.641235  208.638901        0.0        0.0       0.0       0.0
# ...                ...         ...        ...        ...       ...       ...
# 2022-06-23  284.816895  258.311676        0.0        0.0       0.0       0.0
# 2022-06-24  298.308899  267.132996        0.0        0.0       0.0       0.0
# 2022-06-27  291.582825  264.328949        0.0        0.0       0.0       0.0
# 2022-06-28  282.794098  255.936752        0.0        0.0       0.0       0.0
# 2022-06-29  278.818237  259.708740        0.0        0.0       0.0       0.0
#
#                     Cash    TotalAsset
# Date
# 2020-07-01  10000.000000  10000.000000
# 2020-07-02  10000.000000  10000.000000
# 2020-07-06  10000.000000  10000.000000
# 2020-07-07  10000.000000  10000.000000
# 2020-07-08  10000.000000  10000.000000
# ...                  ...           ...
# 2022-06-23  15009.808044  15009.808044
# 2022-06-24  15009.808044  15009.808044
# 2022-06-27  15009.808044  15009.808044
# 2022-06-28  15009.808044  15009.808044
# 2022-06-29  15009.808044  15009.808044
#
# [503 rows x 8 columns]

# %%
portfolio_df.TotalAsset[-1]
# Out:
# 15009.808044433594

# %% [markdown]
# #### Buy-Sell Graph

# %%
fig = plt.figure(figsize=(16,10))

ax1 = fig.add_subplot(111, ylabel='Stock $')
S1.plot(ax=ax1, color='g', lw=2.)
S2.plot(ax=ax1, color='c', lw=2.)


#plot the price when buying
ax1.plot(portfolio_df.loc[portfolio_df.Position1 == 1.0].index,
         portfolio_df.S1[portfolio_df.Position1 == 1.0], '^', markersize=10, color='m')
ax1.plot(portfolio_df.loc[portfolio_df.Position2 == 1.0].index,
         portfolio_df.S2[portfolio_df.Position2 == 1.0], '^', markersize=10, color='m')
#plot the price when selling
ax1.plot(portfolio_df.loc[portfolio_df.Position1 == -1.0].index,
         portfolio_df.S1[portfolio_df.Position1 == -1.0],
         'v', markersize=10, color='k')
ax1.plot(portfolio_df.loc[portfolio_df.Position2 == -1.0].index,
         portfolio_df.S2[portfolio_df.Position2 == -1.0],
         'v', markersize=10, color='k')

plt.legend(['ACN','MSFT', 'Buy Signal', 'Buy Signal', 'Sell Signal', 'Sell Signal'])

#plt.show()
plt.savefig('buy-sell.jpg')

# %% [markdown]
# #### Buy-Sell: Portfolio

# %%
fig = plt.figure(figsize=(12,8))
ax1 = fig.add_subplot(111, ylabel='Portfolio Value $')
portfolio_df['TotalAsset'].plot(ax=ax1, lw=2.)
ax1.plot(portfolio_df.loc[portfolio_df.Position1 == 1.0].index,portfolio_df.TotalAsset[portfolio_df.Position1 == 1.0],'^', markersize=10, color='m')
ax1.plot(portfolio_df.loc[portfolio_df.Position1 == -1.0].index,portfolio_df.TotalAsset[portfolio_df.Position1 == -1.0],'v', markersize=10, color='k')

#plt.show()
plt.savefig('portfolio:buy-sell.jpg')

# %% [markdown]
# #### Portfolio Movement

# %%
portfolio_df[["Holding1", "Holding2", "Cash", "TotalAsset"]].plot(figsize=(16,10))
#plt.show()
plt.savefig('PortfolioMovement.jpg')

# %% [markdown]
# #### Return v.s. S&P 500 Index

# %%
sp500_df = yf.download('^GSPC', start=start_date, end=end_date)
# Out:
# [*********************100%***********************]  1 of 1 completed

# %%
portfolio_df['sp500'] = sp500_df['Adj Close']
portfolio_df['return'] = (portfolio_df['TotalAsset'] - portfolio_df['TotalAsset'][0])/portfolio_df['TotalAsset'][0]
portfolio_df['sp500return'] = (portfolio_df['sp500']-portfolio_df['sp500'][0])/portfolio_df['sp500'][0]

# %%
pd.set_option('display.max_rows', None)

# %%
portfolio_df.to_csv('portfolio1.csv')

# %%
portfolio_df[['return', 'sp500return']].plot()
#plt.show()
plt.savefig('Return.jpg')
